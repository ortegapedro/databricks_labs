# %%
import pyspark
from pyspark.sql import SparkSession                
spark = SparkSession.builder.getOrCreate()

# %%
df_tables = spark.table("information_schema.tables").limit(10)
df_tables.filter(df_tables.table_schema != "default").display()
