# %%
# %sql
CREATE SCHEMA IF NOT EXISTS hive_metastore.bronze;

# %%
# %sql

--jdbc:sqlserver://gizmobox-labs.database.windows.net:1433;database=gizmobox-srv;user=gizmoboxadmin@gizmobox-labs;password={your_password_here};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;
CREATE TABLE IF NOT EXISTS hive_metastore.bronze.refounds
USING JDBC
OPTIONS (
  url "jdbc:sqlserver://gizmobox-labs.database.windows.net:1433;database=gizmobox-srv",
  dbtable "refunds",
  user "gizmoboxadmin",
  password "G1zmo*box"
);

# %%
# %sql
select * from hive_metastore.bronze.refounds;
