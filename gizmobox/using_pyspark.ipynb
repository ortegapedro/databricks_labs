# %%
df = spark.sql('select * from json.`dbfs:/Volumes/gizmobox/landing/operational_data/customers/`')

# %%
df.display()

# %%
spark.read.format('json').load('dbfs:/Volumes/gizmobox/landing/operational_data/customers/').display()

# %%
spark.table('gizmobox.bronze.customers').display()
