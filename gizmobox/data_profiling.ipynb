-- %%
select * from gizmobox.bronze.customers;
-- Out:
-- Databricks data profile. Run in Databricks to view.

-- %%
%python
df = spark.table('gizmobox.bronze.customers')
dbutils.data.summarize(df)

-- %%
select count(*) , count(customer_id), count_if(customer_id is null)
from gizmobox.bronze.customers;
