# %% [markdown]
# # Data brick magic commands
# - %python, %scala, %sql, %r
# - %md markdown for documenting
# - %fs run file system commands
# - %sh Run shell commands
# - %pip install python libraries
# - %run include/import another notebook

# %%
# %fs
ls dbfs:/databricks-datasets/

# %% [markdown]
# # $sh

# %%
# %sh ps

# %% [markdown]
# pip

# %%
# %pip list

# %%
# %pip  install faker

# %%
# %run /Workspace/Users/pedro.in.accenture@gmail.com/dea-course/lab1/databricks_labs/test_pyspark

# %%
items = dbutils.fs.ls("/databricks-datasets/")

# %%
print(items)

# %%
dbutils.fs.help()

# %%
dbutils.fs.help("cp")

# %% [markdown]
# #Create an external location
# -

# %%
# %sql
CREATE EXTERNAL LOCATION adls_raw_zone
URL 'abfss://demo@resourcedatabricks.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL lab_ext_location)
COMMENT 'External location for Demo purposes';

# %%
# %fs ls abfss://demo@resourcedatabricks.dfs.core.windows.net/

# %%
# %fs ls abfss://landing@resourcedatabricks.dfs.core.windows.net/

# %%
# %sql
CREATE EXTERNAL LOCATION adls_landing_zone
URL 'abfss://gizmobox@resourcedatabricks.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL lab_ext_location)
COMMENT 'External location for Demo purposes';

# %%
# %fs ls abfss://gizmobox@resourcedatabricks.dfs.core.windows.net/
